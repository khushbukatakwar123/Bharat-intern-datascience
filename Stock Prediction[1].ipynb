# %% [markdown]
# # Bharat Intern Internship
# ### Task - 1 Name: Stock Prediction Using LSTM
#
# ### Contribution - Individual
#
# ### Submitted by - Khushbu Katakwar

# %% [markdown]
# ### Dataset Summery :
# * This is a Dataset for the Stock prices for the stock of Google. It consists of 7 columns and a smaller subset of 4430 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.

# %% [markdown]
# The columns in the dataset are as follows:
#
# Date: The year,month and date of the stock data.
#
# Close: The closing price of Google's stock on a particular day.
#
# High: The highest value reached by Google's stock on the given day.
#
# Low: The lowest value reached by Google's stock on the given day.
#
# Open: The opening value of Google's stock on the given day.
#
# Volume: The trading volume of Google's stock on the given day.
#
# Adj Close: The adjusted closing price of Google's stock.

# %% [markdown]
# # Let's Begin !
#
# ## Know Your Data :

# %% [markdown]
# ### Import Libraries :

# %%
# Import Libraries
import numpy as np                        #Python library used for working with arrays.
import pandas as pd                       #For data manipulation and analysis
import matplotlib                         #Embedding plots into applications
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns                     #For statistical graphics plotting
from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %% [markdown]
# ### Dataset Loading :

# %%
# Load Dataset
df = pd.read_csv("C:/Users/khush/Desktop/stock.csv")
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    50.050049    52.082081    48.028027    50.220219
# 1     2004-08-20    50.555557    54.594597    50.300301    54.209209
# 2     2004-08-23    55.430431    56.796799    54.579578    54.754753
# 3     2004-08-24    55.675674    55.855858    51.836838    52.487488
# 4     2004-08-25    52.532532    54.054054    51.991993    53.053055
# ...          ...          ...          ...          ...          ...
# 4426  2022-03-18  2668.489990  2724.879883  2645.169922  2722.510010
# 4427  2022-03-21  2723.270020  2741.000000  2681.850098  2722.030029
# 4428  2022-03-22  2722.030029  2821.000000  2722.030029  2797.360107
# 4429  2022-03-23  2774.050049  2791.770020  2756.699951  2765.510010
# 4430  2022-03-24  2784.000000  2832.379883  2755.010010  2831.439941
#
#         Adj Close    Volume
# 0       50.220219  44659096
# 1       54.209209  22834343
# 2       54.754753  18256126
# 3       52.487488  15247337
# 4       53.053055   9188602
# ...           ...       ...
# 4426  2722.510010   2223100
# 4427  2722.030029   1341600
# 4428  2797.360107   1774800
# 4429  2765.510010   1257700
# 4430  2831.439941   1317900
#
# [4431 rows x 7 columns]

# %% [markdown]
# ### Dataset First View :

# %%
# Dataset First Look
df.head()        # Top 5 rows
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659096
# 1  2004-08-20  50.555557  54.594597  50.300301  54.209209  54.209209  22834343
# 2  2004-08-23  55.430431  56.796799  54.579578  54.754753  54.754753  18256126
# 3  2004-08-24  55.675674  55.855858  51.836838  52.487488  52.487488  15247337
# 4  2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188602

# %% [markdown]
# ### Dataset Rows & Columns Count :

# %%
# Dataset Rows & Columns Count
df.shape
# Out:
# (4431, 7)

# %% [markdown]
# ### Dataset Information :

# %%
#Dataset Information
df.info
# Out:
# <bound method DataFrame.info of             Date         Open         High          Low        Close  \
# 0     2004-08-19    50.050049    52.082081    48.028027    50.220219
# 1     2004-08-20    50.555557    54.594597    50.300301    54.209209
# 2     2004-08-23    55.430431    56.796799    54.579578    54.754753
# 3     2004-08-24    55.675674    55.855858    51.836838    52.487488
# 4     2004-08-25    52.532532    54.054054    51.991993    53.053055
# ...          ...          ...          ...          ...          ...
# 4426  2022-03-18  2668.489990  2724.879883  2645.169922  2722.510010
# 4427  2022-03-21  2723.270020  2741.000000  2681.850098  2722.030029
# 4428  2022-03-22  2722.030029  2821.000000  2722.030029  2797.360107
# 4429  2022-03-23  2774.050049  2791.770020  2756.699951  2765.510010
# 4430  2022-03-24  2784.000000  2832.379883  2755.010010  2831.439941
#
#         Adj Close    Volume
# 0       50.220219  44659096
# 1       54.209209  22834343
# 2       54.754753  18256126
# 3       52.487488  15247337
# 4       53.053055   9188602
# ...           ...       ...
# 4426  2722.510010   2223100
# 4427  2722.030029   1341600
# 4428  2797.360107   1774800
# 4429  2765.510010   1257700
# 4430  2831.439941   1317900
#
# [4431 rows x 7 columns]>

# %%
# Checking for data types
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### Duplicate Values :

# %%
#To get all Duplicate Values
df[df.duplicated()].shape
# Out:
# (0, 7)

# %%
#Dataset columns
list(df.columns)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %% [markdown]
# ### Understanding Your Variables :

# %%
#Dataset Describe
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4431.000000  4431.000000  4431.000000  4431.000000  4431.000000
# mean    693.087345   699.735595   686.078751   693.097367   693.097367
# std     645.118799   651.331215   638.579488   645.187806   645.187806
# min      49.644646    50.920921    48.028027    50.055054    50.055054
# 25%     248.558563   250.853355   245.813309   248.415916   248.415916
# 50%     434.924927   437.887878   432.687683   435.330322   435.330322
# 75%    1007.364990  1020.649994   997.274994  1007.790008  1007.790008
# max    3025.000000  3030.929932  2977.979980  2996.770020  2996.770020
#
#              Volume
# count  4.431000e+03
# mean   6.444992e+06
# std    7.690351e+06
# min    4.656000e+05
# 25%    1.695600e+06
# 50%    3.778418e+06
# 75%    8.002390e+06
# max    8.215117e+07

# %% [markdown]
# ### Missing Values/Null Values :

# %%
#To Get All Missing Values/Null Values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']] # Extracting required columns
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('Date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
# <ipython-input-41-ccb42c81a06d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
#                  Open      Close
# Date
# 2004-08-19  50.050049  50.220219
# 2004-08-20  50.555557  54.209209
# 2004-08-23  55.430431  54.754753
# 2004-08-24  55.675674  52.487488
# 2004-08-25  52.532532  53.053055
# 2004-08-26  52.527527  54.009010
# 2004-08-27  54.104103  53.128128
# 2004-08-30  52.692692  51.056057
# 2004-08-31  51.201202  51.236237
# 2004-09-01  51.401402  50.175175

# %%
# Plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# Normalizing Values of columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
# <ipython-input-43-ce7b7f46f471>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] = MMS.fit_transform(df)
#                 Open     Close
# Date
# 2004-08-19  0.000136  0.000056
# 2004-08-20  0.000306  0.001410
# 2004-08-23  0.001945  0.001595
# 2004-08-24  0.002027  0.000825
# 2004-08-25  0.000971  0.001017
# 2004-08-26  0.000969  0.001342
# 2004-08-27  0.001499  0.001043
# 2004-08-30  0.001024  0.000340
# 2004-08-31  0.000523  0.000401
# 2004-09-01  0.000590  0.000041

# %% [markdown]
# ### Splitting Data into a Training set and a Test set :

# %%
#Splitting Data into a Training set and a Test set
train_data = df[:3333]
test_data  = df[3333:]

train_data.shape, test_data.shape
# Out:
# ((3333, 2), (1098, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((3283, 50, 2), (3283, 2), (1048, 50, 2), (1048, 2))

# %% [markdown]
# ### CREATING LSTM MODEL :

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50, 50)            10600
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 103/103 [==============================] - 17s 82ms/step - loss: 7.4356e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0026 - val_mean_absolute_error: 0.0337
# Epoch 2/100
# 103/103 [==============================] - 6s 63ms/step - loss: 4.8371e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0031 - val_mean_absolute_error: 0.0359
# Epoch 3/100
# 103/103 [==============================] - 8s 74ms/step - loss: 4.2422e-05 - mean_absolute_error: 0.0047 - val_loss: 0.0028 - val_mean_absolute_error: 0.0343
# Epoch 4/100
# 103/103 [==============================] - 6s 62ms/step - loss: 4.1873e-05 - mean_absolute_error: 0.0047 - val_loss: 0.0035 - val_mean_absolute_error: 0.0392
# Epoch 5/100
# 103/103 [==============================] - 8s 75ms/step - loss: 4.1560e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0031 - val_mean_absolute_error: 0.0371
# Epoch 6/100
# 103/103 [==============================] - 6s 62ms/step - loss: 4.2109e-05 - mean_absolute_error: 0.0047 - val_loss: 0.0028 - val_mean_absolute_error: 0.0348
# Epoch 7/100
# 103/103 [==============================] - 8s 76ms/step - loss: 3.8416e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0023 - val_mean_absolute_error: 0.0314
# Epoch 8/100
# 103/103 [==============================] - 7s 64ms/step - loss: 3.5650e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0027 - val_mean_absolute_error: 0.0352
# Epoch 9/100
# 103/103 [==============================] - 8s 76ms/step - loss: 3.9577e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0024 - val_mean_absolute_error: 0.0326
# Epoch 10/100
# 103/103 [==============================] - 7s 69ms/step - loss: 3.2719e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0019 - val_mean_absolute_error: 0.0294
# Epoch 11/100
# 103/103 [==============================] - 7s 66ms/step - loss: 3.0925e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 12/100
# 103/103 [==============================] - 8s 73ms/step - loss: 3.4839e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0018 - val_mean_absolute_error: 0.0290
# Epoch 13/100
# 103/103 [==============================] - 8s 82ms/step - loss: 3.0073e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235
# Epoch 14/100
# 103/103 [==============================] - 8s 74ms/step - loss: 3.0349e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0023 - val_mean_absolute_error: 0.0342
# Epoch 15/100
# 103/103 [==============================] - 6s 62ms/step - loss: 3.7269e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0022 - val_mean_absolute_error: 0.0338
# Epoch 16/100
# 103/103 [==============================] - 8s 75ms/step - loss: 3.0424e-05 - mean_absolute_error: 0.0040 - val_loss: 9.9157e-04 - val_mean_absolute_error: 0.0211
# Epoch 17/100
# 103/103 [==============================] - 7s 71ms/step - loss: 3.2510e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 18/100
# 103/103 [==============================] - 7s 67ms/step - loss: 2.6766e-05 - mean_absolute_error: 0.0037 - val_loss: 7.0001e-04 - val_mean_absolute_error: 0.0180
# Epoch 19/100
# 103/103 [==============================] - 8s 75ms/step - loss: 2.6418e-05 - mean_absolute_error: 0.0037 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222
# Epoch 20/100
# 103/103 [==============================] - 8s 76ms/step - loss: 2.7309e-05 - mean_absolute_error: 0.0038 - val_loss: 0.0013 - val_mean_absolute_error: 0.0244
# Epoch 21/100
# 103/103 [==============================] - 8s 76ms/step - loss: 2.3576e-05 - mean_absolute_error: 0.0035 - val_loss: 0.0012 - val_mean_absolute_error: 0.0237
# Epoch 22/100
# 103/103 [==============================] - 6s 63ms/step - loss: 2.4475e-05 - mean_absolute_error: 0.0035 - val_loss: 5.1870e-04 - val_mean_absolute_error: 0.0159
# Epoch 23/100
# 103/103 [==============================] - 8s 74ms/step - loss: 2.4752e-05 - mean_absolute_error: 0.0036 - val_loss: 6.0896e-04 - val_mean_absolute_error: 0.0169
# Epoch 24/100
# 103/103 [==============================] - 6s 62ms/step - loss: 2.2269e-05 - mean_absolute_error: 0.0034 - val_loss: 0.0011 - val_mean_absolute_error: 0.0229
# Epoch 25/100
# 103/103 [==============================] - 8s 74ms/step - loss: 2.7498e-05 - mean_absolute_error: 0.0038 - val_loss: 0.0013 - val_mean_absolute_error: 0.0249
# Epoch 26/100
# 103/103 [==============================] - 8s 74ms/step - loss: 2.2878e-05 - mean_absolute_error: 0.0034 - val_loss: 7.4986e-04 - val_mean_absolute_error: 0.0181
# Epoch 27/100
# 103/103 [==============================] - 6s 61ms/step - loss: 2.0129e-05 - mean_absolute_error: 0.0032 - val_loss: 0.0013 - val_mean_absolute_error: 0.0256
# Epoch 28/100
# 103/103 [==============================] - 8s 74ms/step - loss: 2.2497e-05 - mean_absolute_error: 0.0034 - val_loss: 9.2345e-04 - val_mean_absolute_error: 0.0201
# Epoch 29/100
# 103/103 [==============================] - 7s 63ms/step - loss: 2.1632e-05 - mean_absolute_error: 0.0033 - val_loss: 8.7199e-04 - val_mean_absolute_error: 0.0195
# Epoch 30/100
# 103/103 [==============================] - 8s 75ms/step - loss: 2.1510e-05 - mean_absolute_error: 0.0033 - val_loss: 0.0011 - val_mean_absolute_error: 0.0233
# Epoch 31/100
# 103/103 [==============================] - 6s 61ms/step - loss: 1.9850e-05 - mean_absolute_error: 0.0032 - val_loss: 0.0011 - val_mean_absolute_error: 0.0215
# Epoch 32/100
# 103/103 [==============================] - 8s 74ms/step - loss: 1.8299e-05 - mean_absolute_error: 0.0030 - val_loss: 9.5933e-04 - val_mean_absolute_error: 0.0207
# Epoch 33/100
# 103/103 [==============================] - 6s 63ms/step - loss: 1.8384e-05 - mean_absolute_error: 0.0031 - val_loss: 7.3623e-04 - val_mean_absolute_error: 0.0177
# Epoch 34/100
# 103/103 [==============================] - 8s 74ms/step - loss: 1.7809e-05 - mean_absolute_error: 0.0030 - val_loss: 7.2811e-04 - val_mean_absolute_error: 0.0176
# Epoch 35/100
# 103/103 [==============================] - 6s 62ms/step - loss: 1.6012e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0013 - val_mean_absolute_error: 0.0243
# Epoch 36/100
# 103/103 [==============================] - 8s 73ms/step - loss: 1.8711e-05 - mean_absolute_error: 0.0031 - val_loss: 0.0012 - val_mean_absolute_error: 0.0237
# Epoch 37/100
# 103/103 [==============================] - 8s 74ms/step - loss: 1.7786e-05 - mean_absolute_error: 0.0030 - val_loss: 9.7131e-04 - val_mean_absolute_error: 0.0204
# Epoch 38/100
# 103/103 [==============================] - 6s 63ms/step - loss: 1.5953e-05 - mean_absolute_error: 0.0028 - val_loss: 8.6095e-04 - val_mean_absolute_error: 0.0194
# Epoch 39/100
# 103/103 [==============================] - 8s 74ms/step - loss: 1.5702e-05 - mean_absolute_error: 0.0028 - val_loss: 4.2010e-04 - val_mean_absolute_error: 0.0137
# Epoch 40/100
# 103/103 [==============================] - 6s 62ms/step - loss: 1.6584e-05 - mean_absolute_error: 0.0029 - val_loss: 7.6312e-04 - val_mean_absolute_error: 0.0183
# Epoch 41/100
# 103/103 [==============================] - 7s 69ms/step - loss: 1.5532e-05 - mean_absolute_error: 0.0028 - val_loss: 5.4645e-04 - val_mean_absolute_error: 0.0154
# Epoch 42/100
# 103/103 [==============================] - 6s 62ms/step - loss: 1.5392e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0012 - val_mean_absolute_error: 0.0238
# Epoch 43/100
# 103/103 [==============================] - 7s 69ms/step - loss: 1.4878e-05 - mean_absolute_error: 0.0027 - val_loss: 8.5245e-04 - val_mean_absolute_error: 0.0188
# Epoch 44/100
# 103/103 [==============================] - 6s 61ms/step - loss: 1.7840e-05 - mean_absolute_error: 0.0030 - val_loss: 9.7136e-04 - val_mean_absolute_error: 0.0199
# Epoch 45/100
# 103/103 [==============================] - 7s 68ms/step - loss: 1.4322e-05 - mean_absolute_error: 0.0027 - val_loss: 0.0012 - val_mean_absolute_error: 0.0226
# Epoch 46/100
# 103/103 [==============================] - 8s 73ms/step - loss: 1.5331e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0015 - val_mean_absolute_error: 0.0264
# Epoch 47/100
# 103/103 [==============================] - 6s 62ms/step - loss: 1.5637e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0010 - val_mean_absolute_error: 0.0208
# Epoch 48/100
# 103/103 [==============================] - 7s 71ms/step - loss: 1.2859e-05 - mean_absolute_error: 0.0025 - val_loss: 6.4816e-04 - val_mean_absolute_error: 0.0164
# Epoch 49/100
# 103/103 [==============================] - 6s 62ms/step - loss: 1.6152e-05 - mean_absolute_error: 0.0029 - val_loss: 0.0017 - val_mean_absolute_error: 0.0273
# Epoch 50/100
# 103/103 [==============================] - 7s 71ms/step - loss: 1.3766e-05 - mean_absolute_error: 0.0026 - val_loss: 0.0014 - val_mean_absolute_error: 0.0240
# Epoch 51/100
# 103/103 [==============================] - 7s 70ms/step - loss: 1.8886e-05 - mean_absolute_error: 0.0032 - val_loss: 0.0017 - val_mean_absolute_error: 0.0272
# Epoch 52/100
# 103/103 [==============================] - 7s 65ms/step - loss: 1.3361e-05 - mean_absolute_error: 0.0026 - val_loss: 8.0957e-04 - val_mean_absolute_error: 0.0179
# Epoch 53/100
# 103/103 [==============================] - 8s 79ms/step - loss: 1.4545e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0011 - val_mean_absolute_error: 0.0210
# Epoch 54/100
# 103/103 [==============================] - 7s 64ms/step - loss: 1.2628e-05 - mean_absolute_error: 0.0025 - val_loss: 6.2097e-04 - val_mean_absolute_error: 0.0159
# Epoch 55/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.3693e-05 - mean_absolute_error: 0.0026 - val_loss: 0.0014 - val_mean_absolute_error: 0.0236
# Epoch 56/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.1853e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0015 - val_mean_absolute_error: 0.0248
# Epoch 57/100
# 103/103 [==============================] - 7s 63ms/step - loss: 1.1054e-05 - mean_absolute_error: 0.0024 - val_loss: 0.0026 - val_mean_absolute_error: 0.0325
# Epoch 58/100
# 103/103 [==============================] - 7s 71ms/step - loss: 1.2023e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0012 - val_mean_absolute_error: 0.0215
# Epoch 59/100
# 103/103 [==============================] - 6s 63ms/step - loss: 1.0689e-05 - mean_absolute_error: 0.0023 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 60/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.1756e-05 - mean_absolute_error: 0.0024 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 61/100
# 103/103 [==============================] - 7s 65ms/step - loss: 1.1818e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0023 - val_mean_absolute_error: 0.0310
# Epoch 62/100
# 103/103 [==============================] - 7s 71ms/step - loss: 1.1650e-05 - mean_absolute_error: 0.0024 - val_loss: 0.0015 - val_mean_absolute_error: 0.0247
# Epoch 63/100
# 103/103 [==============================] - 8s 73ms/step - loss: 1.2372e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0012 - val_mean_absolute_error: 0.0208
# Epoch 64/100
# 103/103 [==============================] - 6s 63ms/step - loss: 9.9329e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0027 - val_mean_absolute_error: 0.0336
# Epoch 65/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.0427e-05 - mean_absolute_error: 0.0023 - val_loss: 0.0019 - val_mean_absolute_error: 0.0261
# Epoch 66/100
# 103/103 [==============================] - 6s 63ms/step - loss: 1.1309e-05 - mean_absolute_error: 0.0024 - val_loss: 6.6531e-04 - val_mean_absolute_error: 0.0160
# Epoch 67/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.0579e-05 - mean_absolute_error: 0.0023 - val_loss: 0.0022 - val_mean_absolute_error: 0.0286
# Epoch 68/100
# 103/103 [==============================] - 8s 75ms/step - loss: 1.1353e-05 - mean_absolute_error: 0.0025 - val_loss: 6.1787e-04 - val_mean_absolute_error: 0.0153
# Epoch 69/100
# 103/103 [==============================] - 7s 65ms/step - loss: 1.2168e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0014 - val_mean_absolute_error: 0.0220
# Epoch 70/100
# 103/103 [==============================] - 7s 72ms/step - loss: 9.4140e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0014 - val_mean_absolute_error: 0.0224
# Epoch 71/100
# 103/103 [==============================] - 7s 64ms/step - loss: 9.2805e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0022 - val_mean_absolute_error: 0.0290
# Epoch 72/100
# 103/103 [==============================] - 7s 71ms/step - loss: 9.6279e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0017 - val_mean_absolute_error: 0.0261
# Epoch 73/100
# 103/103 [==============================] - 7s 72ms/step - loss: 1.1421e-05 - mean_absolute_error: 0.0024 - val_loss: 0.0013 - val_mean_absolute_error: 0.0214
# Epoch 74/100
# 103/103 [==============================] - 7s 64ms/step - loss: 9.2758e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0026 - val_mean_absolute_error: 0.0292
# Epoch 75/100
# 103/103 [==============================] - 7s 70ms/step - loss: 9.4665e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0012 - val_mean_absolute_error: 0.0209
# Epoch 76/100
# 103/103 [==============================] - 7s 64ms/step - loss: 9.5865e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0023 - val_mean_absolute_error: 0.0278
# Epoch 77/100
# 103/103 [==============================] - 8s 73ms/step - loss: 1.0020e-05 - mean_absolute_error: 0.0022 - val_loss: 0.0017 - val_mean_absolute_error: 0.0243
# Epoch 78/100
# 103/103 [==============================] - 7s 70ms/step - loss: 8.9661e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0023 - val_mean_absolute_error: 0.0272
# Epoch 79/100
# 103/103 [==============================] - 7s 66ms/step - loss: 9.6716e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0026 - val_mean_absolute_error: 0.0292
# Epoch 80/100
# 103/103 [==============================] - 7s 72ms/step - loss: 8.8240e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0018 - val_mean_absolute_error: 0.0251
# Epoch 81/100
# 103/103 [==============================] - 7s 65ms/step - loss: 8.9124e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0021 - val_mean_absolute_error: 0.0265
# Epoch 82/100
# 103/103 [==============================] - 7s 72ms/step - loss: 8.8596e-06 - mean_absolute_error: 0.0021 - val_loss: 5.4072e-04 - val_mean_absolute_error: 0.0140
# Epoch 83/100
# 103/103 [==============================] - 7s 70ms/step - loss: 9.6351e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0016 - val_mean_absolute_error: 0.0243
# Epoch 84/100
# 103/103 [==============================] - 7s 66ms/step - loss: 8.9901e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0018 - val_mean_absolute_error: 0.0251
# Epoch 85/100
# 103/103 [==============================] - 7s 72ms/step - loss: 8.8065e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0018 - val_mean_absolute_error: 0.0233
# Epoch 86/100
# 103/103 [==============================] - 8s 73ms/step - loss: 9.3181e-06 - mean_absolute_error: 0.0022 - val_loss: 0.0053 - val_mean_absolute_error: 0.0461
# Epoch 87/100
# 103/103 [==============================] - 8s 74ms/step - loss: 1.0190e-05 - mean_absolute_error: 0.0023 - val_loss: 9.6942e-04 - val_mean_absolute_error: 0.0181
# Epoch 88/100
# 103/103 [==============================] - 8s 75ms/step - loss: 7.6924e-06 - mean_absolute_error: 0.0019 - val_loss: 0.0027 - val_mean_absolute_error: 0.0316
# Epoch 89/100
# 103/103 [==============================] - 7s 64ms/step - loss: 1.0726e-05 - mean_absolute_error: 0.0024 - val_loss: 9.4106e-04 - val_mean_absolute_error: 0.0183
# Epoch 90/100
# 103/103 [==============================] - 8s 73ms/step - loss: 8.1364e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0020 - val_mean_absolute_error: 0.0249
# Epoch 91/100
# 103/103 [==============================] - 7s 65ms/step - loss: 7.8424e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0012 - val_mean_absolute_error: 0.0212
# Epoch 92/100
# 103/103 [==============================] - 7s 72ms/step - loss: 7.8528e-06 - mean_absolute_error: 0.0019 - val_loss: 5.4761e-04 - val_mean_absolute_error: 0.0137
# Epoch 93/100
# 103/103 [==============================] - 8s 74ms/step - loss: 8.0796e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0040 - val_mean_absolute_error: 0.0344
# Epoch 94/100
# 103/103 [==============================] - 7s 64ms/step - loss: 8.4602e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0049 - val_mean_absolute_error: 0.0377
# Epoch 95/100
# 103/103 [==============================] - 7s 73ms/step - loss: 7.9534e-06 - mean_absolute_error: 0.0020 - val_loss: 8.4442e-04 - val_mean_absolute_error: 0.0166
# Epoch 96/100
# 103/103 [==============================] - 7s 65ms/step - loss: 8.8084e-06 - mean_absolute_error: 0.0021 - val_loss: 0.0020 - val_mean_absolute_error: 0.0266
# Epoch 97/100
# 103/103 [==============================] - 8s 74ms/step - loss: 7.2583e-06 - mean_absolute_error: 0.0019 - val_loss: 0.0055 - val_mean_absolute_error: 0.0386
# Epoch 98/100
# 103/103 [==============================] - 8s 74ms/step - loss: 8.4890e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0012 - val_mean_absolute_error: 0.0209
# Epoch 99/100
# 103/103 [==============================] - 7s 65ms/step - loss: 8.5228e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0017 - val_mean_absolute_error: 0.0244
# Epoch 100/100
# 103/103 [==============================] - 7s 73ms/step - loss: 8.1110e-06 - mean_absolute_error: 0.0020 - val_loss: 0.0040 - val_mean_absolute_error: 0.0374

# %%
# predicting the values

test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 33/33 [==============================] - 1s 18ms/step
# array([[0.37341565, 0.37721494],
#        [0.37493166, 0.37877175],
#        [0.37451077, 0.37833047],
#        [0.37135985, 0.3751236 ],
#        [0.37320644, 0.37718418]], dtype=float32)

# %%
# Inversing normalization on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1160.6888, 1161.6   ],
#        [1165.1996, 1166.1874],
#        [1163.9473, 1164.8871],
#        [1154.5721, 1155.4374],
#        [1160.0664, 1161.5093]], dtype=float32)

# %% [markdown]
# ### VISUALIZING ACTUAL VS PREDICTED DATA :

# %%
# Merging actual and predicted data.
Merge_df = pd.concat([df.iloc[-1048:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['Open_predicted','Close_predicted'],
                                       index=df.iloc[-1048:].index)], axis=1)

# %%
# Inversing normalization
Merge_df[['Open','Close']] = MMS.inverse_transform(Merge_df[['Open','Close']])
Merge_df.head()
# Out:
#                    Open        Close  Open_predicted  Close_predicted
# Date
# 2018-01-26  1187.530029  1187.560059     1160.688843      1161.599976
# 2018-01-29  1188.000000  1186.479980     1165.199585      1166.187378
# 2018-01-30  1177.719971  1177.369995     1163.947266      1164.887085
# 2018-01-31  1183.810059  1182.219971     1154.572144      1155.437378
# 2018-02-01  1175.989990  1181.589966     1160.066406      1161.509277

# %%
# plotting the actual predicted open prices.
Merge_df[['Open','Open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual predicted close prices.
Merge_df[['Close','Close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ### UPCOMING 15 DAYS PREDICTION:

# %%
# Creating a dataframe and adding 15 days.

Merge_df = Merge_df.append(pd.DataFrame(columns=Merge_df.columns,
                                        index=pd.date_range(start=Merge_df.index[-1], periods=11, freq='D', closed='right')))
Merge_df['2022-02-01':'2022-02-15']
# Out:
# <ipython-input-55-4c1bafada78c>:4: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   index=pd.date_range(start=Merge_df.index[-1], periods=11, freq='D', closed='right')))
# <ipython-input-55-4c1bafada78c>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Merge_df = Merge_df.append(pd.DataFrame(columns=Merge_df.columns,
#                    Open        Close  Open_predicted  Close_predicted
# 2022-02-01  2751.889893  2752.879883     2333.723877      2320.448242
# 2022-02-02  3025.000000  2960.000000     2386.000000      2371.501465
# 2022-02-03  2914.110107  2861.800049     2607.824219      2593.656006
# 2022-02-04  2868.889893  2865.860107     2405.733398      2380.136719
# 2022-02-07  2885.000000  2784.020020     2468.218018      2451.163818
# 2022-02-08  2780.530029  2787.979980     2354.864746      2337.303711
# 2022-02-09  2819.270020  2831.840088     2376.230957      2364.769043
# 2022-02-10  2794.070068  2772.399902     2410.900391      2400.891846
# 2022-02-11  2772.000000  2685.649902     2343.434326      2330.924316
# 2022-02-14  2665.129883  2710.520020     2286.529053      2275.134277
# 2022-02-15  2751.409912  2732.169922     2306.146240      2298.003662

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['Open','Close'],index=Merge_df.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['Open','Close']] = MMS.inverse_transform(upcoming_prediction[['Open','Close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(Merge_df.loc['2022-01-01':,'Open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2022-01-01':,'Open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price Prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(Merge_df.loc['2022-01-01':,'Close'],label='Current Close Price')
ax.plot(upcoming_prediction.loc['2022-01-01':,'Close'],label='Upcoming Close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Close Price Prediction',size=15)
ax.legend()
fig.show()
